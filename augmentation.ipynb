# %% [markdown]
# ### <b>Image augmentation for INPUT: <b style="color:red">128x128</b></b>

# %%
import os
import cv2
import numpy as np
import shutil

# %%
class Augmentation:
    def __init__(self, random_bound=0.5):
        self.random_bound = random_bound
    
    def augment_image(self, image, rotate=True):
        # Randomly flip the image horizontally (left-right)
        if np.random.rand() > self.random_bound:
            image = cv2.flip(image, 1)

        # Fixed rotations (90°, 45°, 180°)
        if rotate:
            # Choose a random fixed angle from the list
            angle = np.random.choice([90, 180, 270])
            height, width = image.shape[:2]
            center = (width // 2, height // 2)
            rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1)
            image = cv2.warpAffine(image, rotation_matrix, (width, height))

        # Random brightness adjustment
        factor = np.random.uniform(1.0, 1.05)
        image = cv2.convertScaleAbs(image, alpha=factor, beta=0)
        return image
    
    def augment_image_file(self, path_to_input_image, path_to_output_image, rotate=True):
        image = cv2.imread(path_to_input_image)
        image = self.augment_image(image)
        cv2.imwrite(path_to_output_image, image)

# %% [markdown]
# #### HELPING ####

# %%
n_images = 100
augmenter = Augmentation()
path = "./final-dataset/imbalanced_flags/I"
category = "I"
files = os.listdir(path)
last_id = -1
for file in files:
    print(file)
    id = int(file.split("_")[1].split(".")[0])
    if id > last_id:
        last_id = id
for i in range(n_images):
    selected_id = np.random.randint(0, last_id-1) + 1
    if selected_id < 10:
        selected_id = f"0{selected_id}"
    last_id = last_id + 1
    path_to_selected_image = f"{path}/{category}_{selected_id}.jpg"
    path_to_generate_image = f"{path}/{category}_{last_id}.jpg"
    print(f"Path to selected image: {path_to_selected_image}")
    print(f"Path to generate image: {path_to_generate_image}\n")
    augmenter.augment_image_file(
        path_to_selected_image,
        path_to_generate_image,
        True
    )
# Out:
# I_01.jpg
# I_02.jpg
# I_03.jpg
# I_04.jpg
# I_05.jpg
# I_06.jpg
# I_07.jpg
# I_08.jpg
# I_09.jpg
# I_10.jpg
# I_100.jpg
# I_101.jpg
# I_102.jpg
# I_103.jpg
# I_104.jpg
# I_105.jpg
# I_106.jpg
# I_107.jpg
# I_108.jpg
# I_109.jpg
# I_11.jpg
# I_110.jpg
# I_111.jpg
# I_112.jpg
# I_113.jpg
# I_114.jpg
# I_115.jpg
# I_116.jpg
# I_117.jpg
# I_12.jpg
# I_13.jpg
# I_14.jpg
# I_15.jpg
# I_16.jpg
# I_17.jpg
# I_18.jpg
# I_19.jpg
# I_20.jpg
# I_21.jpg
# I_22.jpg
# I_23.jpg
# I_24.jpg
# I_25.jpg
# I_26.jpg
# I_27.jpg
# I_28.jpg
# I_29.jpg
# I_30.jpg
# I_31.jpg
# I_32.jpg
# I_33.jpg
# I_34.jpg
# I_35.jpg
# I_36.jpg
# I_37.jpg
# I_38.jpg
# I_39.jpg
# I_40.jpg
# I_41.jpg
# I_42.jpg
# I_43.jpg
# I_44.jpg
# I_45.jpg
# I_46.jpg
# I_47.jpg
# I_48.jpg
# I_49.jpg
# I_50.jpg
# I_51.jpg
# I_52.jpg
# I_53.jpg
# I_54.jpg
# I_55.jpg
# I_56.jpg
# I_57.jpg
# I_58.jpg
# I_59.jpg
# I_60.jpg
# I_61.jpg
# I_62.jpg
# I_63.jpg
# I_64.jpg
# I_65.jpg
# I_66.jpg
# I_67.jpg
# I_68.jpg
# I_69.jpg
# I_70.jpg
# I_71.jpg
# I_72.jpg
# I_73.jpg
# I_74.jpg
# I_75.jpg
# I_76.jpg
# I_77.jpg
# I_78.jpg
# I_79.jpg
# I_80.jpg
# I_81.jpg
# I_82.jpg
# I_83.jpg
# I_84.jpg
# I_85.jpg
# I_86.jpg
# I_87.jpg
# I_88.jpg
# I_89.jpg
# I_90.jpg
# I_91.jpg
# I_92.jpg
# I_93.jpg
# I_94.jpg
# I_95.jpg
# I_96.jpg
# I_97.jpg
# I_98.jpg
# I_99.jpg
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_42.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_118.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_79.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_119.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_02.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_120.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_08.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_121.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_06.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_122.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_58.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_123.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_114.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_124.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_38.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_125.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_106.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_126.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_87.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_127.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_89.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_128.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_01.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_129.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_119.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_130.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_57.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_131.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_16.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_132.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_126.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_133.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_104.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_134.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_07.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_135.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_81.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_136.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_52.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_137.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_94.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_138.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_120.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_139.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_81.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_140.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_22.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_141.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_48.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_142.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_90.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_143.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_100.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_144.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_70.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_145.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_20.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_146.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_12.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_147.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_104.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_148.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_38.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_149.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_102.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_150.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_56.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_151.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_93.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_152.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_142.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_153.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_07.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_154.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_41.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_155.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_125.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_156.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_138.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_157.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_148.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_158.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_88.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_159.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_33.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_160.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_117.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_161.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_151.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_162.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_28.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_163.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_06.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_164.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_15.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_165.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_125.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_166.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_32.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_167.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_80.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_168.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_125.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_169.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_16.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_170.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_113.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_171.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_105.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_172.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_38.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_173.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_163.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_174.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_145.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_175.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_125.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_176.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_72.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_177.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_148.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_178.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_99.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_179.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_24.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_180.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_123.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_181.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_51.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_182.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_12.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_183.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_34.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_184.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_118.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_185.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_62.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_186.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_41.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_187.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_97.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_188.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_83.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_189.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_53.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_190.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_46.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_191.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_94.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_192.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_01.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_193.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_50.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_194.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_71.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_195.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_10.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_196.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_25.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_197.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_159.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_198.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_175.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_199.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_127.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_200.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_114.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_201.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_138.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_202.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_92.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_203.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_121.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_204.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_181.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_205.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_118.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_206.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_167.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_207.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_109.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_208.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_78.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_209.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_108.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_210.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_104.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_211.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_100.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_212.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_184.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_213.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_39.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_214.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_48.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_215.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_61.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_216.jpg
#
# Path to selected image: ./final-dataset/imbalanced_flags/I/I_76.jpg
# Path to generate image: ./final-dataset/imbalanced_flags/I/I_217.jpg

# %% [markdown]
# #### -------------------- ####

# %%
class AugmentationBalancer:
    def __init__(self, random_bound=0.5):
        self.augmentation = Augmentation(random_bound=random_bound)
    
    def fit(self, path_to_folder, delta=5, debug=False):
        self.path_to_folder=path_to_folder        
        directories = os.listdir(path_to_folder)
        real_directories = {}
        self.to_generate = {}
        for directory in directories:
            if os.path.isdir(f"{path_to_folder}/{directory}"):
                count = len(os.listdir(f"{path_to_folder}/{directory}"))
                real_directories[directory]=count
        max_id = max(real_directories)
        self.total_classes = [key for key in real_directories]
        for directory in real_directories:
            diff = real_directories[max_id] - real_directories[directory]
            if(diff>delta):
                self.to_generate[directory]=diff
        if debug:
            print(self.to_generate)
        
    def balance(self, path_to_folder, debug=False):
        for category in self.total_classes:
            source_folder = f"{self.path_to_folder}/{category}"
            destination_folder =f"{path_to_folder}/{category}"
            if os.path.exists(destination_folder) and os.path.isdir(destination_folder):
                shutil.rmtree(destination_folder)
            shutil.copytree(source_folder, destination_folder)
        if debug:
            print(self.to_generate)
        for category in self.to_generate:
            last_id = -1
            for file in os.listdir(f"{path_to_folder}/{category}"):
                id = int(file.split("_")[1].split(".")[0])
                if id > last_id:
                    last_id = id
            for i in range(self.to_generate[category]):
                selected_id = np.random.randint(0, last_id-1) + 1
                if selected_id < 10:
                    selected_id = f"0{selected_id}"
                last_id = last_id + 1
                path_to_selected_image = f"{path_to_folder}/{category}/{category}_{selected_id}.jpg"
                path_to_generate_image = f"{path_to_folder}/{category}/{category}_{last_id}.jpg"
                if debug:
                    print(f"Path to selected image: {path_to_selected_image}")
                    print(f"Path to generate image: {path_to_generate_image}\n")
                self.augmentation.augment_image_file(
                    path_to_selected_image,
                    path_to_generate_image
                )
    
aug_balancer = AugmentationBalancer()
aug_balancer.fit("./dataset/training/imbalanced_flags", debug=True)
aug_balancer.balance("./dataset/training/balanced_flags/", debug=True)
# Out:
# {'China': 20, 'Germany': 7, 'India': 57}
# {'China': 20, 'Germany': 7, 'India': 57}
# Path to selected image: ./dataset/training/balanced_flags//China/China_72.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_80.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_03.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_81.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_73.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_82.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_75.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_83.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_02.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_84.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_05.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_85.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_33.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_86.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_62.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_87.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_01.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_88.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_39.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_89.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_76.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_90.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_70.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_91.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_24.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_92.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_49.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_93.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_77.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_94.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_10.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_95.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_12.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_96.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_13.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_97.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_61.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_98.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//China/China_73.jpg
# Path to generate image: ./dataset/training/balanced_flags//China/China_99.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_13.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_93.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_18.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_94.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_68.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_95.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_20.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_96.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_90.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_97.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_33.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_98.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//Germany/Germany_82.jpg
# Path to generate image: ./dataset/training/balanced_flags//Germany/Germany_99.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_34.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_43.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_08.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_44.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_25.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_45.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_17.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_46.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_21.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_47.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_33.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_48.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_21.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_49.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_44.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_50.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_04.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_51.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_43.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_52.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_10.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_53.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_20.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_54.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_28.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_55.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_44.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_56.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_12.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_57.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_31.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_58.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_33.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_59.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_50.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_60.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_25.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_61.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_09.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_62.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_44.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_63.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_58.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_64.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_63.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_65.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_23.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_66.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_21.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_67.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_28.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_68.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_61.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_69.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_38.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_70.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_39.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_71.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_44.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_72.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_46.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_73.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_61.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_74.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_21.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_75.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_26.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_76.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_11.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_77.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_21.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_78.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_61.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_79.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_14.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_80.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_35.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_81.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_48.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_82.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_18.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_83.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_17.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_84.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_10.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_85.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_72.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_86.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_29.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_87.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_28.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_88.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_39.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_89.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_09.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_90.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_52.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_91.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_09.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_92.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_25.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_93.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_66.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_94.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_52.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_95.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_22.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_96.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_31.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_97.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_79.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_98.jpg
#
# Path to selected image: ./dataset/training/balanced_flags//India/India_33.jpg
# Path to generate image: ./dataset/training/balanced_flags//India/India_99.jpg
