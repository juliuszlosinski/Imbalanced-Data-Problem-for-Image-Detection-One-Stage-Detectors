# %% [markdown]
# ### <b>Image augmentation for INPUT: <b style="color:red">128x128</b></b>

# %%
import os
import cv2
import numpy as np
import shutil

# %%
class Augmentation:
    def __init__(self, random_bound=0.5):
        self.random_bound = random_bound
    
    def augment_image(self, image, rotate=True):
        if np.random.rand() > self.random_bound:
            image = cv2.flip(image, 1)
        if rotate:
            angle = np.random.choice([90, 180, 270])
            height, width = image.shape[:2]
            center = (width // 2, height // 2)
            rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1)
            image = cv2.warpAffine(image, rotation_matrix, (width, height))
        factor = np.random.uniform(1.0, 1.05)
        image = cv2.convertScaleAbs(image, alpha=factor, beta=0)
        return image
    
    def augment_image_file(self, path_to_input_image, path_to_output_image, rotate=True):
        image = cv2.imread(path_to_input_image)
        image = self.augment_image(image)
        cv2.imwrite(path_to_output_image, image)

# %%
class AugmentationBalancer:
    def __init__(self, random_bound=0.5):
        self.augmentation = Augmentation(random_bound=random_bound)
    
    def fit(self, path_to_folder, delta=5, debug=False):
        self.path_to_folder=path_to_folder        
        directories = os.listdir(path_to_folder)
        real_directories = {}
        self.to_generate = {}
        for directory in directories:
            if os.path.isdir(f"{path_to_folder}/{directory}"):
                count = len(os.listdir(f"{path_to_folder}/{directory}"))
                real_directories[directory]=count
        max_id = max(real_directories, key=real_directories.get)
        print(real_directories)
        self.total_classes = [key for key in real_directories]
        for directory in real_directories:
            diff = real_directories[max_id] - real_directories[directory]
            if(diff>delta):
                self.to_generate[directory]=diff
        if debug:
            print(self.to_generate)
        
    def balance(self, path_to_folder, debug=False):
        for category in self.total_classes:
            source_folder = f"{self.path_to_folder}/{category}"
            destination_folder =f"{path_to_folder}/{category}"
            if os.path.exists(destination_folder) and os.path.isdir(destination_folder):
                shutil.rmtree(destination_folder)
            shutil.copytree(source_folder, destination_folder)
        if debug:
            print(self.to_generate)
        for category in self.to_generate:
            last_id = -1
            for file in os.listdir(f"{path_to_folder}/{category}"):
                id = int(file.split("_")[1].split(".")[0])
                if id > last_id:
                    last_id = id
            for i in range(self.to_generate[category]):
                selected_id = np.random.randint(0, last_id-1) + 1
                if selected_id < 10:
                    selected_id = f"0{selected_id}"
                last_id = last_id + 1
                path_to_selected_image = f"{path_to_folder}/{category}/{category}_{selected_id}.jpg"
                path_to_generate_image = f"{path_to_folder}/{category}/{category}_{last_id}.jpg"
                if debug:
                    print(f"Path to selected image: {path_to_selected_image}")
                    print(f"Path to generate image: {path_to_generate_image}\n")
                self.augmentation.augment_image_file(
                    path_to_selected_image,
                    path_to_generate_image
                )
    
aug_balancer = AugmentationBalancer()
aug_balancer.fit("./final-dataset/imbalanced_flags", debug=True)
aug_balancer.balance("./final-dataset/balanced_flags/", debug=True)
# Out:
# {'A': 400, 'B': 200, 'C': 200, 'D': 200, 'E': 200, 'F': 200, 'G': 200, 'H': 200, 'I': 200, 'J': 200, 'K': 200, 'L': 200, 'M': 200, 'N': 200, 'O': 200, 'P': 200, 'Q': 200, 'R': 200, 'S': 200, 'T': 200, 'U': 200, 'V': 200, 'W': 200, 'X': 200, 'Y': 200, 'Z': 200}
# {'B': 200, 'C': 200, 'D': 200, 'E': 200, 'F': 200, 'G': 200, 'H': 200, 'I': 200, 'J': 200, 'K': 200, 'L': 200, 'M': 200, 'N': 200, 'O': 200, 'P': 200, 'Q': 200, 'R': 200, 'S': 200, 'T': 200, 'U': 200, 'V': 200, 'W': 200, 'X': 200, 'Y': 200, 'Z': 200}
# {'B': 200, 'C': 200, 'D': 200, 'E': 200, 'F': 200, 'G': 200, 'H': 200, 'I': 200, 'J': 200, 'K': 200, 'L': 200, 'M': 200, 'N': 200, 'O': 200, 'P': 200, 'Q': 200, 'R': 200, 'S': 200, 'T': 200, 'U': 200, 'V': 200, 'W': 200, 'X': 200, 'Y': 200, 'Z': 200}
# Path to selected image: ./final-dataset/balanced_flags//B/B_126.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_201.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_44.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_202.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_151.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_203.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_79.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_204.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_103.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_205.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_156.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_206.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_171.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_207.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_169.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_208.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_141.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_209.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_126.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_210.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_127.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_211.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_49.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_212.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_135.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_213.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_82.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_214.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_73.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_215.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_176.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_216.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_161.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_217.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_170.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_218.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_88.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_219.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_152.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_220.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_160.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_221.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_177.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_222.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_02.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_223.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_134.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_224.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_27.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_225.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_75.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_226.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_90.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_227.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_09.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_228.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_73.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_229.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_65.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_230.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_144.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_231.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_05.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_232.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_63.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_233.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_176.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_234.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_29.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_235.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_161.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_236.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_48.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_237.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_61.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_238.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_151.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_239.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_53.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_240.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_97.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_241.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_149.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_242.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_23.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_243.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_40.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_244.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_55.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_245.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_205.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_246.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_68.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_247.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_49.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_248.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_163.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_249.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_01.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_250.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_207.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_251.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_156.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_252.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_39.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_253.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_188.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_254.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_18.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_255.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_60.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_256.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_235.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_257.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_03.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_258.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_188.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_259.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_177.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_260.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_28.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_261.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_42.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_262.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_244.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_263.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_120.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_264.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_130.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_265.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_55.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_266.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_163.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_267.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_177.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_268.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_93.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_269.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_92.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_270.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_45.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_271.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_268.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_272.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_04.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_273.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_67.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_274.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_203.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_275.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_262.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_276.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_32.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_277.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_129.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_278.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_151.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_279.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_21.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_280.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_111.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_281.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_158.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_282.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_183.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_283.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_84.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_284.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_215.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_285.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_52.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_286.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_111.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_287.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_147.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_288.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_272.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_289.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_284.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_290.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_245.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_291.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_241.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_292.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_128.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_293.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_58.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_294.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_207.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_295.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_269.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_296.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_100.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_297.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_253.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_298.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_154.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_299.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_218.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_300.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_181.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_301.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_169.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_302.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_157.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_303.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_200.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_304.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_287.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_305.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_74.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_306.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_266.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_307.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_169.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_308.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_275.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_309.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_237.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_310.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_50.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_311.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_07.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_312.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_304.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_313.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_262.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_314.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_257.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_315.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_11.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_316.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_309.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_317.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B_137.jpg
# Path to generate image: ./final-dataset/balanced_flags//B/B_318.jpg
#
# Path to selected image: ./final-dataset/balanced_flags//B/B